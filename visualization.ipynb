# %%
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
G = nx.Graph()
G.add_node("Trump")
G.add_edge("Trump", "Independent", w=round(0.33235672,3))
G.add_edge("Trump", "Criminal", w=round(0.3150612,3))
G.add_edge("Trump", "Firm", w=round(0.28860354,3))
G.add_edge("Trump", "Strong", w=round(0.27453557,3))
G.add_edge("Trump", "Driving", w=round(0.27342603,3))
G.add_edge("Trump", "Serious", w=round(0.25874627,3))
G.add_edge("Trump", "Conservative", w=round(0.2566788,3))
G.add_edge("Trump", "Weak", w=round(0.25541803,3))

G.add_edge("Independent", "Anxious", w=round(0.31803983,3))
G.add_edge("Independent", "Secure", w=round(0.31636095,3))
G.add_edge("Independent", "Ordinary", w=round(0.27514604,3))

G.add_edge("Criminal", "Corrupt", w=round(0.47706005,3))
G.add_edge("Criminal", "Crooked", w=round(0.4442568,3))
G.add_edge("Criminal", "Dirty", w=round(0.32686472,3))

G.add_edge("Firm", "Passive", w=round(0.30992517,3))
G.add_edge("Firm", "Dishonest", w=round(0.2942091,3))
G.add_edge("Firm", "Private", w=round(0.29115742,3))

G.add_edge("Strong", "Weak", w=round(0.42050332,3))
G.add_edge("Strong", "Careless", w=round(0.28526545,3))
G.add_edge("Strong", "Blunt", w=round(0.28262955,3))

G.add_edge("Driving", "Educated", w=round(0.28517485,3))
G.add_edge("Driving", "Stupid", w=round(0.28411043,3))
G.add_edge("Driving", "Extreme", w=round(0.25255653,3))

G.add_edge("Serious", "Messy", w=round(0.42762864,3))
G.add_edge("Serious", "Stupid", w=round(0.375908,3))
G.add_edge("Serious", "Crazy", w=round(0.3148204,3))

G.add_edge("Conservative", "Religious", w=round(0.43823212,3))
G.add_edge("Conservative", "Decent", w=round(0.37339848,3))
G.add_edge("Conservative", "Outspoken", w=round(0.35518676,3))

G.add_edge("Weak", "Ignorant", w=round(0.44330728,3))
G.add_edge("Weak", "Stupid", w=round(0.43967238,3))
G.add_edge("Weak", "Strong", w=round(0.42050332,3))

G.nodes()
# Out:
# NodeView(('Trump', 'Independent', 'Criminal', 'Firm', 'Strong', 'Driving', 'Serious', 'Conservative', 'Weak', 'Anxious', 'Secure', 'Ordinary', 'Corrupt', 'Crooked', 'Dirty', 'Passive', 'Dishonest', 'Private', 'Careless', 'Blunt', 'Educated', 'Stupid', 'Extreme', 'Messy', 'Crazy', 'Religious', 'Decent', 'Outspoken', 'Ignorant'))

# %%
l = list(G.nodes())
#l[9:]

# %%
l1 = tuple([l[0]])
l2 = tuple([l[1:9]])
l3 = tuple([l[9:]])

l4 = tuple([l[1:]])
shell = tuple([l1, l4])

# %%
plt.figure(1, figsize=(25,25))

pos = nx.spring_layout(G,)
nx.draw(G, node_color='aliceblue', pos=pos, edge_color='#909090', node_size=2000)
nx.draw_networkx_labels(G, pos=pos, font_size=28, font_color='dimgray')
e = nx.draw_networkx_edge_labels(G, pos=pos, font_size=20, font_color='dimgray', edge_color='#909090')
plt.savefig("Graph.png", format="PNG")
